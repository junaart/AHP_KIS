# %% [markdown]
# # **Темы докладов**

# %% [markdown]
# 1. Сети массового обслуживания - идеи, основная теория (Карташевский) (до 3 докладов)
# 2. Обзор алгоритмов планировщика заданий в операционных системах (Stewart Weiss) (до 3 докладов)
# 3. Самоподобие (фрактальность) интернет трафика (Карташевский) (до 2 докладов)
# 4. Моделирование производительности Web-систем (Web+simmer) (до 2 докладов)
# 5. Прогнозирование рабочей нагрузки Web-систем (Web+simmer) (до 2 докладов)
# 6. Анализ систем с неэкспоненциальными распределениями (M/G/1) и влияние коэффициента вариации на длину очереди. (Формулы Поллачика-Хинчина+simmer) (до 2 докладов)
